# %%
# !pip3 install understat
# Out:
# Requirement already satisfied: understat in f:\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: bs4 in f:\anaconda3\lib\site-packages (from understat) (0.0.1)
# Requirement already satisfied: pytest-aiohttp in f:\anaconda3\lib\site-packages (from understat) (0.3.0)
# Requirement already satisfied: pytest in f:\anaconda3\lib\site-packages (from understat) (3.5.1)
# Requirement already satisfied: aiohttp in f:\anaconda3\lib\site-packages (from understat) (3.5.4)
# Requirement already satisfied: codecov in f:\anaconda3\lib\site-packages (from understat) (2.0.15)
# Requirement already satisfied: pytest-mock in f:\anaconda3\lib\site-packages (from understat) (1.10.4)
# Requirement already satisfied: pytest-cov in f:\anaconda3\lib\site-packages (from understat) (2.7.1)
# Requirement already satisfied: beautifulsoup4 in f:\anaconda3\lib\site-packages (from bs4->understat) (4.6.0)
# Requirement already satisfied: py>=1.5.0 in f:\anaconda3\lib\site-packages (from pytest->understat) (1.5.3)
# Requirement already satisfied: six>=1.10.0 in f:\anaconda3\lib\site-packages (from pytest->understat) (1.11.0)
# Requirement already satisfied: setuptools in f:\anaconda3\lib\site-packages (from pytest->understat) (39.1.0)
# Requirement already satisfied: attrs>=17.4.0 in f:\anaconda3\lib\site-packages (from pytest->understat) (18.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in f:\anaconda3\lib\site-packages (from pytest->understat) (4.1.0)
# Requirement already satisfied: pluggy<0.7,>=0.5 in f:\anaconda3\lib\site-packages (from pytest->understat) (0.6.0)
# Requirement already satisfied: colorama in f:\anaconda3\lib\site-packages (from pytest->understat) (0.3.9)
# Requirement already satisfied: chardet<4.0,>=2.0 in f:\anaconda3\lib\site-packages (from aiohttp->understat) (3.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in f:\anaconda3\lib\site-packages (from aiohttp->understat) (1.3.0)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in f:\anaconda3\lib\site-packages (from aiohttp->understat) (1.1.0)
# Requirement already satisfied: multidict<5.0,>=4.0 in f:\anaconda3\lib\site-packages (from aiohttp->understat) (4.5.2)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in f:\anaconda3\lib\site-packages (from aiohttp->understat) (3.7.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in f:\anaconda3\lib\site-packages (from aiohttp->understat) (3.0.1)
# Requirement already satisfied: requests>=2.7.9 in f:\anaconda3\lib\site-packages (from codecov->understat) (2.18.4)
# Requirement already satisfied: coverage in f:\anaconda3\lib\site-packages (from codecov->understat) (4.5.2)
# Requirement already satisfied: idna>=2.0 in f:\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->understat) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in f:\anaconda3\lib\site-packages (from requests>=2.7.9->codecov->understat) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda3\lib\site-packages (from requests>=2.7.9->codecov->understat) (2019.3.9)
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !python -m pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/5c/e0/be401c003291b56efc55aeba6a80ab790d3d4cece2778288d65323009420/pip-19.1.1-py2.py3-none-any.whl (1.4MB)
# Installing collected packages: pip
#   Found existing installation: pip 19.0.1
#     Uninstalling pip-19.0.1:
#       Successfully uninstalled pip-19.0.1
# Successfully installed pip-19.1.1

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('E0.csv')

# %% [markdown]
# # Notes for Football Data
# ### http://www.football-data.co.uk/notes.txt
# All data is in csv format, ready for use within standard spreadsheet applications. Please note that some abbreviations are no longer in use (in particular odds from specific bookmakers no longer used) and refer to data collected in earlier seasons. For a current list of what bookmakers are included in the dataset please visit http://www.football-data.co.uk/matches.php
#
# Key to results data:
#
#     Div = League Division
#     Date = Match Date (dd/mm/yy)
#     HomeTeam = Home Team
#     AwayTeam = Away Team
#     FTHG and HG = Full Time Home Team Goals
#     FTAG and AG = Full Time Away Team Goals
#     FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
#     HTHG = Half Time Home Team Goals
#     HTAG = Half Time Away Team Goals
#     HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
# Match Statistics (where available)
#
#     Attendance = Crowd Attendance
#     Referee = Match Referee
#     HS = Home Team Shots
#     AS = Away Team Shots
#     HST = Home Team Shots on Target
#     AST = Away Team Shots on Target
#     HHW = Home Team Hit Woodwork
#     AHW = Away Team Hit Woodwork
#     HC = Home Team Corners
#     AC = Away Team Corners
#     HF = Home Team Fouls Committed
#     AF = Away Team Fouls Committed
#     HFKC = Home Team Free Kicks Conceded
#     AFKC = Away Team Free Kicks Conceded
#     HO = Home Team Offsides
#     AO = Away Team Offsides
#     HY = Home Team Yellow Cards
#     AY = Away Team Yellow Cards
#     HR = Home Team Red Cards
#     AR = Away Team Red Cards
#     HBP = Home Team Bookings Points (10 = yellow, 25 = red)
#     ABP = Away Team Bookings Points (10 = yellow, 25 = red)
#
# Note that Free Kicks Conceeded includes fouls, offsides and any other offense commmitted and will always be equal to or higher than the number of fouls. Fouls make up the vast majority of Free Kicks Conceded. Free Kicks Conceded are shown when specific data on Fouls are not available (France 2nd, Belgium 1st and Greece 1st divisions).

# %%
data.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA',
#        'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
#        'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
data.loc[:,'Div':'AR']
# Out:
#     Div        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  10/08/2018      Man United       Leicester     2     1   H     1
# 1    E0  11/08/2018     Bournemouth         Cardiff     2     0   H     1
# 2    E0  11/08/2018          Fulham  Crystal Palace     0     2   A     0
# 3    E0  11/08/2018    Huddersfield         Chelsea     0     3   A     0
# 4    E0  11/08/2018       Newcastle       Tottenham     1     2   A     1
# 5    E0  11/08/2018         Watford        Brighton     2     0   H     1
# 6    E0  11/08/2018          Wolves         Everton     2     2   D     1
# 7    E0  12/08/2018         Arsenal        Man City     0     2   A     0
# 8    E0  12/08/2018       Liverpool        West Ham     4     0   H     2
# 9    E0  12/08/2018     Southampton         Burnley     0     0   D     0
# 10   E0  18/08/2018         Cardiff       Newcastle     0     0   D     0
# 11   E0  18/08/2018         Chelsea         Arsenal     3     2   H     2
# 12   E0  18/08/2018         Everton     Southampton     2     1   H     2
# 13   E0  18/08/2018       Leicester          Wolves     2     0   H     2
# 14   E0  18/08/2018       Tottenham          Fulham     3     1   H     1
# 15   E0  18/08/2018        West Ham     Bournemouth     1     2   A     1
# 16   E0  19/08/2018        Brighton      Man United     3     2   H     3
# 17   E0  19/08/2018         Burnley         Watford     1     3   A     1
# 18   E0  19/08/2018        Man City    Huddersfield     6     1   H     3
# 19   E0  20/08/2018  Crystal Palace       Liverpool     0     2   A     0
# 20   E0  25/08/2018         Arsenal        West Ham     3     1   H     1
# 21   E0  25/08/2018     Bournemouth         Everton     2     2   D     0
# 22   E0  25/08/2018    Huddersfield         Cardiff     0     0   D     0
# 23   E0  25/08/2018       Liverpool        Brighton     1     0   H     1
# 24   E0  25/08/2018     Southampton       Leicester     1     2   A     0
# 25   E0  25/08/2018          Wolves        Man City     1     1   D     0
# 26   E0  26/08/2018          Fulham         Burnley     4     2   H     3
# 27   E0  26/08/2018       Newcastle         Chelsea     1     2   A     0
# 28   E0  26/08/2018         Watford  Crystal Palace     2     1   H     0
# 29   E0  27/08/2018      Man United       Tottenham     0     3   A     0
# ..   ..         ...             ...             ...   ...   ...  ..   ...
# 340  E0  20/04/2019        West Ham       Leicester     2     2   D     1
# 341  E0  20/04/2019          Wolves        Brighton     0     0   D     0
# 342  E0  21/04/2019         Arsenal  Crystal Palace     2     3   A     0
# 343  E0  21/04/2019         Cardiff       Liverpool     0     2   A     0
# 344  E0  21/04/2019         Everton      Man United     4     0   H     2
# 345  E0  22/04/2019         Chelsea         Burnley     2     2   D     2
# 346  E0  23/04/2019       Tottenham        Brighton     1     0   H     0
# 347  E0  23/04/2019         Watford     Southampton     1     1   D     0
# 348  E0  24/04/2019      Man United        Man City     0     2   A     0
# 349  E0  24/04/2019          Wolves         Arsenal     3     1   H     3
# 350  E0  26/04/2019       Liverpool    Huddersfield     5     0   H     3
# 351  E0  27/04/2019        Brighton       Newcastle     1     1   D     0
# 352  E0  27/04/2019  Crystal Palace         Everton     0     0   D     0
# 353  E0  27/04/2019          Fulham         Cardiff     1     0   H     0
# 354  E0  27/04/2019     Southampton     Bournemouth     3     3   D     1
# 355  E0  27/04/2019       Tottenham        West Ham     0     1   A     0
# 356  E0  27/04/2019         Watford          Wolves     1     2   A     0
# 357  E0  28/04/2019         Burnley        Man City     0     1   A     0
# 358  E0  28/04/2019       Leicester         Arsenal     3     0   H     0
# 359  E0  28/04/2019      Man United         Chelsea     1     1   D     1
# 360  E0  03/05/2019         Everton         Burnley     2     0   H     2
# 361  E0  04/05/2019     Bournemouth       Tottenham     1     0   H     0
# 362  E0  04/05/2019         Cardiff  Crystal Palace     2     3   A     1
# 363  E0  04/05/2019       Newcastle       Liverpool     2     3   A     1
# 364  E0  04/05/2019        West Ham     Southampton     3     0   H     1
# 365  E0  04/05/2019          Wolves          Fulham     1     0   H     0
# 366  E0  05/05/2019         Arsenal        Brighton     1     1   D     1
# 367  E0  05/05/2019         Chelsea         Watford     3     0   H     0
# 368  E0  05/05/2019    Huddersfield      Man United     1     1   D     0
# 369  E0  06/05/2019        Man City       Leicester     1     0   H     0
#
#      HTAG HTR ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0       0   H ...   6    4  11   8   2   5   2   1   0   0
# 1       0   H ...   4    1  11   9   7   4   1   1   0   0
# 2       1   A ...   6    9   9  11   5   5   1   2   0   0
# 3       2   A ...   1    4   9   8   2   5   2   1   0   0
# 4       2   A ...   2    5  11  12   3   5   2   2   0   0
# 5       0   H ...   5    0  10  16   8   2   2   2   0   0
# 6       1   D ...   4    5   8   7   3   6   0   1   0   1
# 7       1   A ...   3    8  11  14   2   9   2   2   0   0
# 8       0   H ...   8    2  14   9   5   4   1   2   0   0
# 9       0   D ...   3    6  10   9   8   5   0   1   0   0
# 10      0   D ...   1    6  14  16   5   5   2   2   0   1
# 11      2   D ...  11    6  12   9   5   1   0   2   0   0
# 12      0   H ...   7    4   8  20   2   5   0   5   0   0
# 13      0   H ...   2    3  10   8   1   9   2   1   1   0
# 14      0   H ...  11    3   9   5   5   2   0   0   0   0
# 15      0   H ...   5    5  14  10   6   4   6   2   0   0
# 16      1   H ...   3    3  16  13   3   5   1   1   0   0
# 17      1   D ...   3    6   8  19   5   2   1   2   0   0
# 18      1   H ...  14    1   9   4  10   3   0   2   0   0
# 19      1   A ...   2    6   6  13   6   7   1   1   1   0
# 20      1   D ...  10    5  16  13  10   2   1   3   0   0
# 21      0   D ...   5    3  12  10   6   2   0   3   1   1
# 22      0   D ...   1    4   8  10   7   7   0   1   1   0
# 23      0   H ...   8    2   8  14   8   5   1   1   0   0
# 24      0   D ...   5    5  13  11  10   3   1   1   1   0
# 25      0   D ...   2    6  13   8   5   9   1   2   0   0
# 26      2   H ...  12    2  11   8   6   4   2   1   0   0
# 27      0   D ...   2    3  16   8   4   5   3   1   0   0
# 28      0   D ...   5    3  14  11   6   3   4   2   0   0
# 29      0   D ...   5    5  11  16   5   2   2   4   0   0
# ..    ...  .. ...  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..
# 340     0   H ...   3    5   8   9   6   8   2   0   0   0
# 341     0   D ...   5    0   0   8  14   1   0   1   0   0
# 342     1   A ...   5    7  15  12   8   3   4   1   0   0
# 343     0   D ...   2    6   6   5   5  10   1   1   0   0
# 344     0   H ...   8    1  11   7  10   2   1   1   0   0
# 345     2   D ...   3    3  10  11   5  10   3   1   0   0
# 346     0   D ...   5    1   7  13   6   3   1   2   0   0
# 347     1   A ...   4    4  10  14   3   4   5   2   0   0
# 348     0   D ...   1    5  10  10   1   1   2   2   0   0
# 349     0   H ...   3    1  12   9   5   5   2   3   0   0
# 350     0   H ...   7    1   5  14   4   4   0   0   0   0
# 351     1   A ...   2    1   7  10   7   4   2   3   0   0
# 352     0   D ...   0    3   9  15   5  10   2   0   0   0
# 353     0   D ...   2    8  10   8  10   3   0   0   0   0
# 354     2   A ...   7    5   8   9   9   3   2   1   0   0
# 355     0   D ...   4    7   3   8   2   7   0   2   0   0
# 356     1   A ...   1    4  10  11   4   5   3   2   0   0
# 357     0   D ...   0    7   5   7   0   6   1   1   0   0
# 358     0   D ...  12    1  13  13   8   6   3   1   0   1
# 359     1   D ...   5    3   9  14   6   6   3   2   0   0
# 360     0   H ...   6    1   8   9   8   1   0   2   0   0
# 361     0   D ...   6    5  11  12  10   6   1   5   0   2
# 362     2   A ...   8    7  14  11  10   5   0   0   0   0
# 363     2   A ...   7    4  10   4   2   3   1   1   0   0
# 364     0   H ...   6    1   2  11   2   7   1   1   0   0
# 365     0   D ...   6    2  10  15   7   1   1   3   0   0
# 366     0   H ...   8    5   9  14  16   3   5   2   0   0
# 367     0   D ...   9    3   6  12   6   6   0   1   0   0
# 368     1   A ...   3    7  10  10   3   7   1   1   0   0
# 369     0   D ...   5    2  12   5  11   0   3   2   0   0
#
# [370 rows x 23 columns]

# %%
from understat import Understat

# %%
import asyncio
import json

import aiohttp

from understat import Understat

df = pd.DataFrame()
s = ""

async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        grouped_stats = await understat.get_player_grouped_stats(619)
        s = json.dumps(grouped_stats)
        print(s)
        df = pd.read_json(s)
        return s
    
loop = asyncio.get_event_loop()
s = loop.run_until_complete(main())
loop.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-82-42bb345e37f8> in <module>()
#      19
#      20 loop = asyncio.get_event_loop()
# ---> 21 s = loop.run_until_complete(main())
#      22 loop.close()
#
# F:\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# F:\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     407         self._check_closed()
#     408         if self.is_running():
# --> 409             raise RuntimeError('This event loop is already running')
#     410         if events._get_running_loop() is not None:
#     411             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# {"season": [{"position": "FW", "games": "32", "goals": "20", "shots": "114", "time": "2425", "xG": "19.303838703781366", "assists": "8", "xA": "5.177165998145938", "key_passes": "33", "season": "2018", "team": "Manchester City", "yellow": "3", "red": "0", "npg": "18", "npxG": "17.78150112554431", "xGChain": "27.935014471411705", "xGBuildup": "8.033177688717842"}, {"position": "FW", "games": "25", "goals": "21", "shots": "95", "time": "1985", "xG": "18.56861797720194", "assists": "6", "xA": "6.533229699358344", "key_passes": "39", "season": "2017", "team": "Manchester City", "yellow": "2", "red": "0", "npg": "17", "npxG": "15.523942567408085", "xGChain": "23.707814872264862", "xGBuildup": "7.512718818150461"}, {"position": "FW", "games": "31", "goals": "20", "shots": "139", "time": "2408", "xG": "22.672585003077984", "assists": "3", "xA": "4.665906261652708", "key_passes": "31", "season": "2016", "team": "Manchester City", "yellow": "4", "red": "1", "npg": "16", "npxG": "18.866740860044956", "xGChain": "25.35206551104784", "xGBuildup": "5.0266740852966905"}, {"position": "Sub", "games": "30", "goals": "24", "shots": "119", "time": "2399", "xG": "20.077213659882545", "assists": "2", "xA": "2.0287597198039293", "key_passes": "27", "season": "2015", "team": "Manchester City", "yellow": "1", "red": "0", "npg": "20", "npxG": "16.271369472146034", "xGChain": "18.786789989098907", "xGBuildup": "3.925958522595465"}, {"position": "Sub", "games": "33", "goals": "26", "shots": "148", "time": "2551", "xG": "25.270159743726254", "assists": "8", "xA": "5.568922242149711", "key_passes": "33", "season": "2014", "team": "Manchester City", "yellow": "4", "red": "0", "npg": "21", "npxG": "20.70318364351988", "xGChain": "27.805154908448458", "xGBuildup": "6.878173082135618"}], "position": {"2018": {"FW": {"position": "FW", "games": "30", "goals": "20", "shots": "113", "time": "2376", "xG": "19.252417162060738", "assists": "8", "xA": "5.177165998145938", "key_passes": "33", "season": "2018", "yellow": "3", "red": "0", "npg": "18", "npxG": "17.73007958382368", "xGChain": "27.866396240890026", "xGBuildup": "8.015980999916792"}, "Sub": {"position": "Sub", "games": "2", "goals": "0", "shots": "1", "time": "49", "xG": "0.05142154172062874", "assists": "0", "xA": "0", "key_passes": "0", "season": "2018", "yellow": "0", "red": "0", "npg": "0", "npxG": "0.05142154172062874", "xGChain": "0.06861823052167892", "xGBuildup": "0.017196688801050186"}}, "2017": {"FW": {"position": "FW", "games": "22", "goals": "21", "shots": "89", "time": "1882", "xG": "18.079133190214634", "assists": "6", "xA": "6.4558263551443815", "key_passes": "38", "season": "2017", "yellow": "0", "red": "0", "npg": "17", "npxG": "15.03445778042078", "xGChain": "23.100842356681824", "xGBuildup": "7.408911912702024"}, "Sub": {"position": "Sub", "games": "3", "goals": "0", "shots": "6", "time": "103", "xG": "0.4894847869873047", "assists": "0", "xA": "0.07740334421396255", "key_passes": "1", "season": "2017", "yellow": "2", "red": "0", "npg": "0", "npxG": "0.4894847869873047", "xGChain": "0.6069725155830383", "xGBuildup": "0.10380690544843674"}}, "2016": {"FW": {"position": "FW", "games": "25", "goals": "19", "shots": "126", "time": "2227", "xG": "20.002017997205257", "assists": "3", "xA": "4.561210986226797", "key_passes": "30", "season": "2016", "yellow": "3", "red": "1", "npg": "15", "npxG": "16.957342691719532", "xGChain": "23.016430415213108", "xGBuildup": "4.548745305277407"}, "Sub": {"position": "Sub", "games": "6", "goals": "1", "shots": "13", "time": "181", "xG": "2.6705670058727264", "assists": "0", "xA": "0.10469527542591095", "key_passes": "1", "season": "2016", "yellow": "1", "red": "0", "npg": "1", "npxG": "1.9093981683254242", "xGChain": "2.335635095834732", "xGBuildup": "0.4779287800192833"}}, "2015": {"FW": {"position": "FW", "games": "29", "goals": "24", "shots": "117", "time": "2373", "xG": "19.44702084362507", "assists": "2", "xA": "1.9395243097096682", "key_passes": "26",  ...

# %%
s
# Out:
# ''

# %%
import asyncio

async def say(what, when):
    await asyncio.sleep(when)
    print(what)

loop = asyncio.get_event_loop()
loop.run_until_complete(say('hello world', 1))
loop.close()
# Out:
# Task exception was never retrieved
# future: <Task finished coro=<main() done, defined at <ipython-input-52-2437b7aa7f95>:9> exception=AttributeError("'Understat' object has no attribute 'get_players'",)>
# Traceback (most recent call last):
#   File "<ipython-input-52-2437b7aa7f95>", line 12, in main
#     player = await understat.get_players(
# AttributeError: 'Understat' object has no attribute 'get_players'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-58-bf3ae2bf3a96> in <module>()
#       6
#       7 loop = asyncio.get_event_loop()
# ----> 8 loop.run_until_complete(say('hello world', 5))
#       9 loop.close()
#
# F:\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# F:\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     407         self._check_closed()
#     408         if self.is_running():
# --> 409             raise RuntimeError('This event loop is already running')
#     410         if events._get_running_loop() is not None:
#     411             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# hello world

# %%
async def set_after(fut, delay, value):
    # Sleep for *delay* seconds.
    await asyncio.sleep(delay)

    # Set *value* as a result of *fut* Future.
    fut.set_result(value)

async def main():
    # Get the current event loop.
    loop = asyncio.get_running_loop()

    # Create a new Future object.
    fut = loop.create_future()

    # Run "set_after()" coroutine in a parallel Task.
    # We are using the low-level "loop.create_task()" API here because
    # we already have a reference to the event loop at hand.
    # Otherwise we could have just used "asyncio.create_task()".
    loop.create_task(
        set_after(fut, 1, '... world'))

    print('hello ...')

    # Wait until *fut* has a result (1 second) and print it.
    print(await fut)

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-bfc07cd6988a> in <module>()
#      25     print(await fut)
#      26
# ---> 27 asyncio.run(main())
#
# AttributeError: module 'asyncio' has no attribute 'run'
